# %%
import cv2

import os

import matplotlib.pyplot as plt

# %matplotlib inline 

frame_num = [566, 605, 610, 630, 650] 

person_0 = [(730, 1165),(740, 1175),(699, 1078),(702, 1082),(699, 1078),(686, 1078)]

person_1 = [(757, 1277), (752, 1279), (734, 1184), (734, 1190), (714, 1138), (712, 1134)]

person_2 = [(771, 1342), (782, 1349), (733, 1234), (734, 1245), (712, 1160), (718, 1167)]

frames_dir = "/Users/sam/code/honoursProject/data/frames"

# %%
i566 = os.path.join(frames_dir, str(frame_num[0]) + ".jpg")

img_566 = cv2.imread(i566)

cc = plt.Circle(person_0[1], 1)

plt.imshow(img_566)
plt.title("Frame 566")
plt.show()

# %%
from matplotlib import image
from matplotlib import pyplot as plt

# to read the image stored in the working directory
data = image.imread("/Users/sam/code/honoursProject/data/frames/566.jpg")

plt.plot(730, 1165, marker='v', color="white")

plt.imshow(data)
plt.show()
