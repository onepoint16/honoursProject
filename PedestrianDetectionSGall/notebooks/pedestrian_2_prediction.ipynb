# %%
# Import Memspectrum
from memspectrum import MESA

import numpy as np

np.random.seed(0)

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Making dataset from pedestrian 2 movments 

# Pedestrian 2
person_2_X = [782, 774, 789, 766, 760, 753, 739, 739, 725, 729]

person_2_Y = [1452, 1422, 1367, 1332, 1305, 1271, 1246, 1228, 1212, 1186]

# %%
N, dt = 10, 1  # Number of samples and sampling interval
no_pred = 2
time = np.arange(0, N) * dt

plt.plot(time[:-1], person_2_X[:-1], color = 'k')
plt.title("Person 1 X coordinate")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time[:-1], person_2_Y[:-1], color = 'k')
plt.title("Person 1 Y coordinate")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

# %%
M = MESA()
M.solve(person_2_X[:-no_pred])
forecast = M.forecast(person_2_X[:-no_pred], length = no_pred, number_of_simulations = no_pred*1000, 
include_data = False)
median_X = np.median(forecast, axis = 0) # Ensemble median
average_X = np.average(forecast, axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/v9/wbd2v3k97txgb4qp7z43g6wm0000gn/T/ipykernel_80931/2085556842.py in <module>
#       1 M = MESA()
#       2 M.solve(person_2_X[:-no_pred])
# ----> 3 forecast = M.forecast(person_2_X[:-no_pred], length = no_pred, number_of_simulations = no_pred*1000,
#       4 include_data = False)
#       5 median_X = np.median(forecast, axis = 0) # Ensemble median
#
# ~/opt/anaconda3/envs/bigdata/lib/python3.9/site-packages/memspectrum/memspectrum.py in forecast(self, data, length, number_of_simulations, P, include_data, seed, verbose)
#     839             assert data.ndim == 1, ValueError("Wrong number of dimension for data: 1 dim expcted but got {} dims".format(data.ndim))
#     840             if len(data) >= p:
# --> 841                 predictions[:,:p] = data[-p:]
#     842             else:
#     843                 raise ValueError("Data are not long enough for forecasting")
#
# ValueError: could not broadcast input array from shape (8,) into shape (2000,0)

# %%
M.solve(person_2_Y[:-no_pred])
forecast = M.forecast(person_2_Y[:-no_pred], length = no_pred, number_of_simulations = no_pred*10000, 
include_data = False)
median_Y = np.median(forecast, axis = 0) # Ensemble median
average_Y = np.average(forecast, axis=0)

# %%
plt.plot(time, person_2_X, color = 'k')
plt.plot(time[N-no_pred:], person_2_X[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_X, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_X, color = 'b', label = 'average estimate')
plt.title("Person 1 X coordinate prediction")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/v9/wbd2v3k97txgb4qp7z43g6wm0000gn/T/ipykernel_80931/741909878.py in <module>
#       1 plt.plot(time, person_2_X, color = 'k')
#       2 plt.plot(time[N-no_pred:], person_2_X[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
# ----> 3 plt.plot(time[N-no_pred:], median_X, color = 'r', label = 'median estimate')
#       4 plt.plot(time[N-no_pred:], average_X, color = 'b', label = 'average estimate')
#       5 plt.title("Person 1 X coordinate prediction")
#
# NameError: name 'median_X' is not defined

# %%
plt.plot(time, person_2_Y, color = 'k')
plt.plot(time[N-no_pred:], person_2_Y[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_Y, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_Y, color = 'b', label = 'average estimate')
plt.title("Person 1 Y coordinate prediction")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

# %%
real_X_values = person_2_X[N-no_pred:]
print("Real X Values = ", real_X_values)
print("Median X Values = ", median_X)
print("Average X Value = ", average_X)
SSE_X = np.sum((real_X_values - median_X)**2)
SSR_X = np.sum((real_X_values - average_X)**2)
SST_X = np.sum(SSR_X + SSE_X)
print("SSE X = ", SSE_X)
print("SSR X = ", SSR_X)
print("SST X = ", SST_X)
# Out:
# Real X Values =  [725, 729]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/v9/wbd2v3k97txgb4qp7z43g6wm0000gn/T/ipykernel_80931/1694338562.py in <module>
#       1 real_X_values = person_2_X[N-no_pred:]
#       2 print("Real X Values = ", real_X_values)
# ----> 3 print("Median X Values = ", median_X)
#       4 print("Average X Value = ", average_X)
#       5 SSE_X = np.sum((real_X_values - median_X)**2)
#
# NameError: name 'median_X' is not defined

# %%
# Sum Squared Error just as a quick evaluation

real_Y_values = person_2_Y[N-no_pred:]
print("Real Y Values = ", real_Y_values)

print("Median Y Values = ", median_Y)
print("Average Y Value = ", average_Y)

SSE_Y = np.sum((real_Y_values - median_Y)**2)

SSR_Y = np.sum((real_Y_values - average_Y)**2)

SST_Y = np.sum(SSR_Y + SSE_Y)

print("SSE Y = ", SSE_Y)

print("SSR Y = ", SSR_Y)

print("SST Y = ", SST_Y)
# Out:
# Real Y Values =  [1212, 1186]
# Median Y Values =  [1227.22943929 1227.11349188]
# Average Y Value =  [1227.47695523 1226.95030751]
# SSE Y =  1922.2550358826904
# SSR Y =  1916.4638282509918
# SST Y =  3838.7188641336825

# %%
person_2_final_coordinate = [718, 1148]

print ("Person 1 Final Coordinates: ", str(person_2_final_coordinate))
