# %%
import numpy as np

np.random.seed(0)

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from memspectrum import MESA

import numpy as np

np.random.seed(0)

def get_forecast(data, pred, sims):
    M = MESA()

    M.solve(data)

    forecast = M.forecast(data, length = pred, number_of_simulations = pred*sims, include_data = False)

    return forecast

# %%
# Making dataset from pedestrian 0 movments 

# Dropped first 4 frames
# 767, 765, 759, 753, 755, 752, 753, 753, 745, 746, 746, 740, 730, 727
person_0_X_2 = [755, 752, 753, 753, 745, 746, 746, 740, 730, 727]

# Dropped first 4 frames
# 1243, 1239, 1230, 1227, 1222, 1217, 1217, 1216, 1207, 1198, 1188, 1175, 1165, 1155
person_0_Y_2 = [1222, 1217, 1217, 1216, 1207, 1198, 1188, 1175, 1165, 1155]

# Dropped first 4 frames
# 767, 763, 752, 752, 746, 727, 716, 718, 717, 715, 711, 703, 699, 700
person_0_X_5 = [746, 727, 716, 718, 717, 715, 711, 703, 699, 700]

# Dropped first 4 frames
# 1243, 1229, 1217, 1212, 1188, 1160, 1148, 1139, 1126, 1124, 1101, 1083, 1078, 1076
person_0_Y_5 = [1188, 1160, 1148, 1139, 1126, 1124, 1101, 1083, 1078, 1076]

# Dropped last 4 frames
# 797, 794, 767, 752, 746, 716, 717, 711, 699, 690, 689, 689, 687, 685
person_0_X_10 = [797, 794, 767, 752, 746, 716, 717, 711, 699, 690]

# Dropped last 4 frames
# 1326, 1303, 1243, 1217, 1188, 1148, 1126, 1101, 1078, 1073, 1065, 1058, 1050, 1046
person_0_Y_10 = [1326, 1303, 1243, 1217, 1188, 1148, 1126, 1101, 1078, 1073]

# %%
N, dt = 10, 1  # Number of samples and sampling interval
no_pred = 2
sims = 1000
time = np.arange(0, N) * dt

# %%
plt.plot(time[:-1], person_0_X_2[:-1], color = 'k')
plt.title("Person 0 X coordinate")
plt.xlabel("Frame intervals of 2")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time[:-1], person_0_Y_2[:-1], color = 'k')
plt.title("Person 0 Y coordinate")
plt.xlabel("Frame intervals of 2")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time[:-1], person_0_X_5[:-1], color = 'k')
plt.title("Person 0 X coordinate")
plt.xlabel("Frame intervals of 5")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time[:-1], person_0_Y_5[:-1], color = 'k')
plt.title("Person 0 Y coordinate")
plt.xlabel("Frame intervals of 5")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time[:-1], person_0_X_10[:-1], color = 'k')
plt.title("Person 0 X coordinate")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time[:-1], person_0_Y_10[:-1], color = 'k')
plt.title("Person 0 Y coordinate")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

# %%
forecast_X_2 = get_forecast(person_0_X_2[:-no_pred], no_pred, sims)
median_X_2 = np.median(forecast_X_2, axis = 0) # Ensemble median
average_X_2 = np.average(forecast_X_2, axis=0)

forecast_Y_2 = get_forecast(person_0_Y_2[:-no_pred], no_pred, sims)
median_Y_2 = np.median(forecast_Y_2, axis = 0) # Ensemble median
average_Y_2 = np.average(forecast_Y_2, axis=0)

# %%
forecast_X_5 = get_forecast(person_0_X_5[:-no_pred], no_pred, sims)
median_X_5 = np.median(forecast_X_5, axis = 0) # Ensemble median
average_X_5 = np.average(forecast_X_5, axis=0)

forecast_Y_5 = get_forecast(person_0_Y_5[:-no_pred], no_pred, sims)
median_Y_5 = np.median(forecast_Y_5, axis = 0) # Ensemble median
average_Y_5 = np.average(forecast_Y_5, axis=0)

# %%
forecast_X_10 = get_forecast(person_0_X_10[:-no_pred], no_pred, sims)
median_X_10 = np.median(forecast_X_10, axis = 0) # Ensemble median
average_X_10 = np.average(forecast_X_10, axis=0)

forecast_Y_10 = get_forecast(person_0_Y_10[:-no_pred], no_pred, sims)
median_Y_10 = np.median(forecast_Y_10, axis = 0) # Ensemble median
average_Y_10 = np.average(forecast_Y_10, axis=0)

# %%
plt.plot(time, person_0_X_2, color = 'k')
plt.plot(time[N-no_pred:], person_0_X_2[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_X_2, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_X_2, color = 'b', label = 'average estimate')
plt.title("Person 0 X coordinate prediction")
plt.xlabel("Frame intervals of 2")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time, person_0_Y_2, color = 'k')
plt.plot(time[N-no_pred:], person_0_Y_2[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_Y_2, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_Y_2, color = 'b', label = 'average estimate')
plt.title("Person 0 Y coordinate prediction")
plt.xlabel("Frame intervals of 2")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

# %%
plt.plot(time, person_0_X_5, color = 'k')
plt.plot(time[N-no_pred:], person_0_X_5[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_X_5, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_X_5, color = 'b', label = 'average estimate')
plt.title("Person 0 X coordinate prediction")
plt.xlabel("Frame intervals of 5")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time, person_0_Y_5, color = 'k')
plt.plot(time[N-no_pred:], person_0_Y_5[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_Y_5, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_Y_5, color = 'b', label = 'average estimate')
plt.title("Person 0 Y coordinate prediction")
plt.xlabel("Frame intervals of 5")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

# %%
plt.plot(time, person_0_X_10, color = 'k')
plt.plot(time[N-no_pred:], person_0_X_10[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_X_10, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_X_10, color = 'b', label = 'average estimate')
plt.title("Person 0 X coordinate prediction")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The X coordinate of Pedestrian Centroid")
plt.show()

plt.plot(time, person_0_Y_10, color = 'k')
plt.plot(time[N-no_pred:], person_0_Y_10[N-no_pred:], color = 'g', linestyle = '-.', label = 'Observed data')
plt.plot(time[N-no_pred:], median_Y_10, color = 'r', label = 'median estimate')
plt.plot(time[N-no_pred:], average_Y_10, color = 'b', label = 'average estimate')
plt.title("Person 0 Y coordinate prediction")
plt.xlabel("Frame intervals of 10")
plt.ylabel("The Y coordinate of Pedestrian Centroid")
plt.show()

# %%
real_X_2_values = person_0_X_2[N-no_pred:]
SSE_X_2 = np.sum((real_X_2_values - median_X_2)**2)
SSR_X_2 = np.sum((real_X_2_values - median_X_2)**2)
SST_X_2 = np.sum(SSR_X_2 + SSE_X_2)

real_Y_2_values = person_0_Y_2[N-no_pred:]
SSE_Y_2 = np.sum((real_Y_2_values - median_Y_2)**2)
SSR_Y_2 = np.sum((real_Y_2_values - median_Y_2)**2)
SST_Y_2 = np.sum(SSR_Y_2 + SSE_Y_2)

# %%
real_X_5_values = person_0_X_5[N-no_pred:]
SSE_X_5 = np.sum((real_X_5_values - median_X_5)**2)
SSR_X_5 = np.sum((real_X_5_values - median_X_5)**2)
SST_X_5 = np.sum(SSR_X_5 + SSE_X_5)

real_Y_5_values = person_0_Y_5[N-no_pred:]
SSE_Y_5 = np.sum((real_Y_5_values - median_Y_5)**2)
SSR_Y_5 = np.sum((real_Y_5_values - median_Y_5)**2)
SST_Y_5 = np.sum(SSR_Y_5 + SSE_Y_5)

# %%
real_X_10_values = person_0_X_10[N-no_pred:]
SSE_X_10 = np.sum((real_X_10_values - median_X_10)**2)
SSR_X_10 = np.sum((real_X_10_values - median_X_10)**2)
SST_X_10 = np.sum(SSR_X_10 + SSE_X_10)

real_Y_10_values = person_0_Y_10[N-no_pred:]
SSE_Y_10 = np.sum((real_Y_10_values - median_Y_10)**2)
SSR_Y_10 = np.sum((real_Y_10_values - median_Y_10)**2)
SST_Y_10 = np.sum(SSR_Y_10 + SSE_Y_10)

# %%
print ("Person 0 Final Coordinates: ", "\n", 
"Across 2 frames:", "\n",
"frame 566 prediction : ", "\n",
"Median X: ", str(median_X_2), " Y: ", str(median_Y_2), "\n",
"Mean X: ", str(average_X_2), " Y: ", str(average_Y_2), "\n",
"Actual Value X: ", str(real_X_2_values), " Y: ", str(real_Y_2_values), "\n",
"SSE X: ", str(SSE_X_2), " Y: ", str(SSE_Y_2), "\n",
"SSR X: ", str(SSR_X_2), " Y: ", str(SSR_Y_2), "\n",
"SST X: ", str(SST_X_2), " Y: ", str(SST_Y_2), "\n", "\n",
"Across 5 frames:", "\n", 
"frame 605 prediction: ", "\n",
"Median X: ", str(median_X_5), " Y: ", str(median_Y_5), "\n",
"Mean X: ", str(average_X_5), " Y: ", str(average_Y_5), "\n",
"Actual Value X: ", str(real_X_5_values), " Y: ", str(real_Y_5_values), "\n",
"SSE X: ", str(SSE_X_5), " Y: ", str(SSE_Y_5), "\n",
"SSR X: ", str(SSR_X_5), " Y: ", str(SSR_Y_5), "\n",
"SST X: ", str(SST_X_5), " Y: ", str(SST_Y_5), "\n", "\n",
"Across 10 frames:", "\n", 
"frame 610 prediction: ", "\n",
"Median X: ", str(median_X_10), " Y: ", str(median_Y_10), "\n",
"Mean X: ", str(average_X_10), " Y: ", str(average_Y_10), "\n",
"Actual Value X: ", str(real_X_10_values), " Y: ", str(real_Y_10_values), "\n",
"SSE X: ", str(SSE_X_10), " Y: ", str(SSE_Y_10), "\n",
"SSR X: ", str(SSR_X_10), " Y: ", str(SSR_Y_10), "\n",
"SST X: ", str(SST_X_10), " Y: ", str(SST_Y_10)
)
# Out:
# Person 0 Final Coordinates:
#  Across 2 frames:
#  frame 566 prediction :
#  Median X:  [740.80661413 741.65285043]  Y:  [1174.93989546 1174.89876968]
#  Mean X:  [740.80626722 741.60472968]  Y:  [1175.0104757  1174.92207825]
#  Actual Value X:  [730, 727]  Y:  [1165, 1155]
#  SSE X:  331.4889346943548  Y:  494.76255658185363
#  SSR X:  331.4889346943548  Y:  494.76255658185363
#  SST X:  662.9778693887096  Y:  989.5251131637073
#
#  Across 5 frames:
#  frame 605 prediction:
#  Median X:  [702.5484633  702.40004344]  Y:  [1082.05203428 1083.48140083]
#  Mean X:  [702.5995602  702.53445046]  Y:  [1082.74479914 1083.07441223]
#  Actual Value X:  [699, 700]  Y:  [1078, 1076]
#  SSE X:  18.35180028748803  Y:  72.39034015808049
#  SSR X:  18.35180028748803  Y:  72.39034015808049
#  SST X:  36.70360057497606  Y:  144.78068031616098
#
#  Across 10 frames:
#  frame 610 prediction:
#  Median X:  [686.4152065  689.15649067]  Y:  [1078.92084752 1055.00675711]
# ...
