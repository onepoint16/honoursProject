# %% [markdown]
# # QDTrack multiple object detection and tracking with BDD100K
#
# https://github.com/SysCV/qdtrack/blob/master/docs/GET_STARTED.md

# %% [markdown]
# Location of labels to convert:
#
# /run/media/sam/Dataset/QDTrack/data/bdd/labels-original/det_20
#
# /run/media/sam/Dataset/QDTrack/data/bdd/labels-original/box_track_20
#
# Location to convert to:
#
# /run/media/sam/Dataset/QDTrack/data/bdd/labels/det_20
#
# /run/media/sam/Dataset/QDTrack/data/bdd/labels/box_track_20

# %% [markdown]
# In order to have the following conversion scripts run correctly amendments where made to the bdd100k toolkit within the conda environment.
# ../anaconda3/envs/qdtrack2/lib/python3.7/site-packages/bdd100k-1.0.0-py3.7.egg/bdd100k/label/to_coco.py
#
# Within the file the key value pairs / label names within the bdd100k labels where different to those within the to_coco.py file
#
# on line 145
#
# if frame["labels"] need to be changed to frame.get("labels", none)
#
# within the mot label convesion label names need to be matched to dataset
#
# Conversion code of original label to coco format det 20:
#
# python -m bdd100k.label.to_coco -m det -i /run/media/sam/Dataset/QDTrack/data/bdd/labels-original/det_20/det_train.json -o /run/media/sam/Dataset/QDTrack/data/bdd/labels/det_20/det_train_cocofmt.json
#
# python -m bdd100k.label.to_coco -m det -i /run/media/sam/Dataset/QDTrack/data/bdd/labels-original/det_20/det_val.json -o /run/media/sam/Dataset/QDTrack/data/bdd/labels/det_20/det_val_cocofmt.json
#
#
# BoxTrack 20:
#
# python -m bdd100k.label.to_coco -m track -i /run/media/sam/Dataset/QDTrack/data/bdd/labels-original/box_track_20/train -o /run/media/sam/Dataset/QDTrack/data/bdd/labels/box_track_20/box_track_train_cocofmt.json
#
# python -m bdd100k.label.to_coco -m track -i /run/media/sam/Dataset/QDTrack/data/bdd/labels-original/box_track_20/val -o /run/media/sam/Dataset/QDTrack/data/bdd/labels/box_track_20/box_track_val_cocofmt.json

# %% [markdown]
# ### Running QDTrack
#
# As I have access to a singel GPU (Nvidia 3090) I will follow the script to train with a single GPU
#
# python tools/train.py ${CONFIG_FILE} [optional arguments]
#
# The config file selected will be bdd100k
#
# /run/media/sam/Dataset/QDTrack/configs/bdd100k/qdtrack-frcnn_r50_fpn_12e_bdd100k.py
#
# No optional arguments will be supplied on the first run.
#
# command being entered into terminal conda env:
#
# python tools/train.py /run/media/sam/Dataset/QDTrack/configs/bdd100k/qdtrack-frcnn_r50_fpn_12e_bdd100k.py
#
# error:
#
# Traceback (most recent call last):
#   File "tools/train.py", line 11, in <module>
#     from mmdet.apis import set_random_seed
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmdet/__init__.py", line 25, in <module>
#     f'MMCV=={mmcv.__version__} is used but incompatible. ' \
# AssertionError: MMCV==1.4.3 is used but incompatible. Please install mmcv>=1.3.8, <=1.4.0.
# (qdtrack) [sam@sam QDTrack]$ pip install mmcv==1.3.8
#
#
# pip installmmcv==1.3.8
#
# Re run command
#
# Error:
#
# Traceback (most recent call last):
#   File "tools/train.py", line 11, in <module>
#     from mmdet.apis import set_random_seed
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmdet/apis/__init__.py", line 1, in <module>
#     from .inference import (async_inference_detector, inference_detector,
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmdet/apis/inference.py", line 6, in <module>
#     from mmcv.ops import RoIPool
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmcv/ops/__init__.py", line 1, in <module>
#     from .bbox import bbox_overlaps
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmcv/ops/bbox.py", line 3, in <module>
#     ext_module = ext_loader.load_ext('_ext', ['bbox_overlaps'])
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmcv/utils/ext_loader.py", line 12, in load_ext
#     ext = importlib.import_module('mmcv.' + name)
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ModuleNotFoundError: No module named 'mmcv._ext'
#
# Try and locate missing module
#
# Solutions discussed here: https://github.com/open-mmlab/mmdetection/issues/3271
#
# First will check pytorch is compatable with nvidia and cua version
#
# Nvidia: 495.46
#
# Cuda 11.5
#
# Pytorch 1.10.1
#
# According to forum post pytorch latest will not run with cuda 11.5 but cant find recent confirming source
#
# This forum from pytorch seems to indicate 1.10 will be compatible with 11.x https://discuss.pytorch.org/t/pytorch-with-cuda-11-compatibility/89254/26
#
# so I will move onto mmcv fix before concluding cuda version should be downgraded
#
# Uninstalled version of mmcv:
#
# pip uninstall mmcv mmcv-full
#
#
# Went to mmcv github cloned repo and opened termianl at repo
#
# Command entered to setup mmcv:
#
# MMCV_WITH_OPS=1 python3 -m pip install -e .
#
# installation takin 15 mins +
#
# Tried running qdtrack
#
# Error:
#
# Traceback (most recent call last):
#   File "tools/train.py", line 11, in <module>
#     from mmdet.apis import set_random_seed
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmdet/__init__.py", line 25, in <module>
#     f'MMCV=={mmcv.__version__} is used but incompatible. ' \
# AssertionError: MMCV==1.4.4 is used but incompatible. Please install mmcv>=1.3.8, <=1.4.0.
#
# Having to uninstall mmcv and try with this line
#
# pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu11.5/torch1.10.1/index.html
#
# Return:
#
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu11.5/torch1.10.1/index.html
# Collecting mmcv-full
#   Downloading mmcv-full-1.4.4.tar.gz (420 kB)
#      |████████████████████████████████| 420 kB 2.1 MB/s
# Requirement already satisfied: addict in /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages (from mmcv-full) (2.4.0)
# Requirement already satisfied: numpy in /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages (from mmcv-full) (1.21.5)
# Requirement already satisfied: packaging in /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages (from mmcv-full) (21.3)
# Requirement already satisfied: Pillow in /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages (from mmcv-full) (9.0.0)
# Requirement already satisfied: pyyaml in /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages (from mmcv-full) (6.0)
# Requirement already satisfied: yapf in /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages (from mmcv-full) (0.32.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages (from packaging->mmcv-full) (3.0.7)
# Building wheels for collected packages: mmcv-full
#   Building wheel for mmcv-full (setup.py) ... \
#
# Set up takes 15 min +
#
# Completed but version it donwloads is 1.4.4 which is flaggin as incompatable
#
# Next fix is to install mmcv-full==1.3.8
#
# Error:
#
# Traceback (most recent call last):
#   File "tools/train.py", line 11, in <module>
#     from mmdet.apis import set_random_seed
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmdet/apis/__init__.py", line 1, in <module>
#     from .inference import (async_inference_detector, inference_detector,
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmdet/apis/inference.py", line 6, in <module>
#     from mmcv.ops import RoIPool
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmcv/ops/__init__.py", line 1, in <module>
#     from .bbox import bbox_overlaps
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmcv/ops/bbox.py", line 3, in <module>
#     ext_module = ext_loader.load_ext('_ext', ['bbox_overlaps'])
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmcv/utils/ext_loader.py", line 12, in load_ext
#     ext = importlib.import_module('mmcv.' + name)
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ImportError: /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/mmcv/_ext.cpython-37m-x86_64-linux-gnu.so: undefined symbol: _ZNSt15__exception_ptr13exception_ptr9_M_addrefEv
#
# Found potential issue being conda installing both pytorch cpu and gpu:
#
# https://github.com/pyg-team/pytorch_geometric/issues/999
#
# Shall continue investigation to run tomorrow

# %% [markdown]
# From issues board uninstalling pytorch and installing directly from pytorch ould be a fix
#
# conda uninstall pytorch
#
# Pytorch github: https://github.com/pytorch/pytorch#get-the-pytorch-source
#
# Following source download and installation instructions for linux
#
# git clone --recursive https://github.com/pytorch/pytorch
# cd pytorch
# # if you are updating an existing checkout
# git submodule sync
# git submodule update --init --recursive --jobs 0
#
# export CMAKE_PREFIX_PATH=${CONDA_PREFIX:-"$(dirname $(which conda))/../"}
# python setup.py install
#
# which conda = /home/sam/anaconda3/condabin/conda
#
# conda prefix? = /home/sam/anaconda3/envs/qdtrack/
#
# export CMAKE_PREFIX_PATH=/home/sam/anaconda3/envs/qdtrack/:-"/home/sam/anaconda3/condabin/conda"
# python setup.py install
#
# pip install cmake
#
# Ran commands
#
# Error:
# Traceback (most recent call last):
#   File "tools/train.py", line 8, in <module>
#     import torch
#   File "/home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/torch/__init__.py", line 199, in <module>
#     from torch._C import *  # noqa: F403
# ImportError: /home/sam/anaconda3/envs/qdtrack/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /home/sam/anaconda3/envs/qdtrack/lib/python3.7/site-packages/torch/lib/libtorch_python.so)
#
#
# Attempting to find a solution to activating glibcxx but no luck
#
# https://stackoverflow.com/questions/65349875/where-can-i-find-glibcxx-3-4-29
#
#
# https://forum.manjaro.org/t/missing-glibcxx-3-4-29/72542/2

# %% [markdown]
# Could not fix this so have moved onto another model
#
# Details in log notes jan/22 end
